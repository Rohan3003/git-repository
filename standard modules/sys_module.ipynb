# %%
import sys
sys.version
# Out:
# '3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)]'

# %%
sys.exit
# Out:
# <function sys.exit>

# %%
import sys
for line in sys.stdin:
    if 'q' == line.rstrip():
        break
    print(f'Input : {line}')
print('Exit')

# %%
# sys.path - This variable contains a list of directories that the interpreter will search for required modules.
import sys
sys.path
# Out:
# ['',
#  'd:\\Work\\Coding\\git repository\\Standard modules',
#  'c:\\Users\\rohan\\Anaconda3\\python37.zip',
#  'c:\\Users\\rohan\\Anaconda3\\DLLs',
#  'c:\\Users\\rohan\\Anaconda3\\lib',
#  'c:\\Users\\rohan\\Anaconda3',
#  'c:\\Users\\rohan\\Anaconda3\\lib\\site-packages',
#  'c:\\Users\\rohan\\Anaconda3\\lib\\site-packages\\win32',
#  'c:\\Users\\rohan\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'c:\\Users\\rohan\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'c:\\Users\\rohan\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\rohan\\.ipython']

# %%
# sys.modules - returns the name of modules that the current shell has imported.
import sys
sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'nt': <module 'nt' (built-in)>,
#  'winreg': <module 'winreg' (built-in)>,
#  'encodings': <module 'encodings' from 'c:\\Users\\rohan\\Anaconda3\\lib\\encodings\\__init__.py'>,
#  'codecs': <module 'codecs' from 'c:\\Users\\rohan\\Anaconda3\\lib\\codecs.py'>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'encodings.aliases': <module 'encodings.aliases' from 'c:\\Users\\rohan\\Anaconda3\\lib\\encodings\\aliases.py'>,
# ...

# %%
import sys
sys.argv #
# Out:
# ['c:\\Users\\rohan\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py',
#  '--ip=127.0.0.1',
#  '--stdin=9035',
#  '--control=9033',
#  '--hb=9032',
#  '--Session.signature_scheme="hmac-sha256"',
#  '--Session.key=b"a21ab026-c365-4bbe-9ff7-9fe7f33da4c5"',
#  '--shell=9034',
#  '--transport="tcp"',
#  '--iopub=9036',
#  '--f=c:\\Users\\rohan\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-15540pgOZTJD99aXx.json']

# %%
import sys
print("Script name:", sys.argv[0])

for i,arg in enumerate(sys.argv[1:], 1):
    print(f"Argument {i}: {arg}")
# Out:
# Script name: c:\Users\rohan\Anaconda3\lib\site-packages\ipykernel_launcher.py
# Argument 1: --ip=127.0.0.1
# Argument 2: --stdin=9035
# Argument 3: --control=9033
# Argument 4: --hb=9032
# Argument 5: --Session.signature_scheme="hmac-sha256"
# Argument 6: --Session.key=b"a21ab026-c365-4bbe-9ff7-9fe7f33da4c5"
# Argument 7: --shell=9034
# Argument 8: --transport="tcp"
# Argument 9: --iopub=9036
# Argument 10: --f=c:\Users\rohan\AppData\Roaming\jupyter\runtime\kernel-v2-15540pgOZTJD99aXx.json
