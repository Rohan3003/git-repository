# %%
# creating an empty dataframe
import pandas as pd
df_empty = pd.DataFrame()
df_empty
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df_empty.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
# None

# %% [markdown]
# Creating dataframes

# %%
#1. Creating a dataframe from lists
import pandas as pd
data = [10, 20, 30, 40, 50]
df1 = pd.DataFrame(data=data, columns=['Numbers'])
df1
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50

# %%
# 2. Creating a dataframe from a dictionary
import pandas as pd
data = {'Name':['John', 'Tim', 'Rob'], 'Age':[34, 23, 42]}
df = pd.DataFrame(data=data)
df
# Out:
#    Name  Age
# 0  John   34
# 1   Tim   23
# 2   Rob   42

# %% [markdown]
# Dataframe and its associated methods
# 1) df.info()
# 2) df.describe()
# 3) df.sample()
# 4) df.head()
# 5) df.tail()
# 6) df.size
# 7) df.shape
# 8) df.dtypes
# 9) df.memory_usage()
# 10) df.rename()
# 11) df.loc()
# 12) df.insert()
# 13) df.assign()

# %%
# Creating a standard dataframe with all datatypes 
import pandas as pd
import numpy as np

data = {
    'Employee_ID': [101, 102, 103, 104, 105],
    'First_Name': ['John', 'Alice', 'Bob', 'Eva', 'Silvester'],
    'Last_Name': ['Smith', 'Johnson', 'Brown', 'Davis', 'Smith'],
    'Birth_Date': ['1990-05-15', '1995-03-20', '1985-09-10', '1992-11-25', '1970-04-23'],
    'Hire_Date': pd.to_datetime(['2020-07-01', '2018-04-15', '2015-10-03', '2019-02-12', '2012-06-07']),
    'Salary': [55000.0, 60000.5, 48000.75, 62000.25, 1640000.0],
    'Active': ["Y", " ", "N", "Y", "N"],
    'Department': ['HR', 'Engineering', 'Finance', 'Marketing', 'HR']
}

df = pd.DataFrame(data)
df.head()
# Out:
#    Employee_ID First_Name Last_Name  Birth_Date  Hire_Date      Salary Active  \
# 0          101       John     Smith  1990-05-15 2020-07-01    55000.00      Y
# 1          102      Alice   Johnson  1995-03-20 2018-04-15    60000.50
# 2          103        Bob     Brown  1985-09-10 2015-10-03    48000.75      N
# 3          104        Eva     Davis  1992-11-25 2019-02-12    62000.25      Y
# 4          105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00      N
#
#     Department
# 0           HR
# 1  Engineering
# 2      Finance
# 3    Marketing
# 4           HR

# %%
# to show random rows from a dataframe
df.sample(4)
# Out:
#    Employee_ID First_Name Last_Name  Birth_Date  Hire_Date      Salary Active  \
# 0          101       John     Smith  1990-05-15 2020-07-01    55000.00      Y
# 2          103        Bob     Brown  1985-09-10 2015-10-03    48000.75      N
# 3          104        Eva     Davis  1992-11-25 2019-02-12    62000.25      Y
# 4          105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00      N
#
#   Department
# 0         HR
# 2    Finance
# 3  Marketing
# 4         HR

# %%
# to show the rows from last 5 rows of a dataframe
df.tail()
# Out:
#    Employee_ID First_Name Last_Name  Birth_Date  Hire_Date      Salary Active  \
# 0          101       John     Smith  1990-05-15 2020-07-01    55000.00      Y
# 1          102      Alice   Johnson  1995-03-20 2018-04-15    60000.50
# 2          103        Bob     Brown  1985-09-10 2015-10-03    48000.75      N
# 3          104        Eva     Davis  1992-11-25 2019-02-12    62000.25      Y
# 4          105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00      N
#
#     Department
# 0           HR
# 1  Engineering
# 2      Finance
# 3    Marketing
# 4           HR

# %%
# size of a dataframe - rows * columns
print(df.size)
# Out:
# 40

# %%
# shape of a dataframe - no of rows and columns
print(df.shape)
# Out:
# (5, 8)

# %%
print(df.dtypes)
# Out:
# Employee_ID             int64
# First_Name             object
# Last_Name              object
# Birth_Date             object
# Hire_Date      datetime64[ns]
# Salary                float64
# Active                 object
# Department             object
# dtype: object

# %%
# to return the memory usasge of a dataframe for each column in bytes
df.memory_usage()
# Out:
# Index          132
# Employee_ID     40
# First_Name      40
# Last_Name       40
# Birth_Date      40
# Hire_Date       40
# Salary          40
# Active          40
# Department      40
# dtype: int64

# %%
# to get a concise summary of a dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  5 non-null      int64
#  1   First_Name   5 non-null      object
#  2   Last_Name    5 non-null      object
#  3   Birth_Date   5 non-null      object
#  4   Hire_Date    5 non-null      datetime64[ns]
#  5   Salary       5 non-null      float64
#  6   Active       5 non-null      object
#  7   Department   5 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#        Employee_ID            Hire_Date        Salary
# count     5.000000                    5  5.000000e+00
# mean    103.000000  2017-03-20 14:24:00  3.730003e+05
# min     101.000000  2012-06-07 00:00:00  4.800075e+04
# 25%     102.000000  2015-10-03 00:00:00  5.500000e+04
# 50%     103.000000  2018-04-15 00:00:00  6.000050e+04
# 75%     104.000000  2019-02-12 00:00:00  6.200025e+04
# max     105.000000  2020-07-01 00:00:00  1.640000e+06
# std       1.581139                  NaN  7.082950e+05

# %%
for index, value in df.iterrows():
    print(index, value)
# Out:
# 0 Employee_ID                    101
# First_Name                    John
# Last_Name                    Smith
# Birth_Date              1990-05-15
# Hire_Date      2020-07-01 00:00:00
# Salary                     55000.0
# Active                           Y
# Department                      HR
# Name: 0, dtype: object
# 1 Employee_ID                    102
# First_Name                   Alice
# Last_Name                  Johnson
# Birth_Date              1995-03-20
# Hire_Date      2018-04-15 00:00:00
# Salary                     60000.5
# Active
# Department             Engineering
# Name: 1, dtype: object
# 2 Employee_ID                    103
# First_Name                     Bob
# Last_Name                    Brown
# Birth_Date              1985-09-10
# Hire_Date      2015-10-03 00:00:00
# Salary                    48000.75
# Active                           N
# Department                 Finance
# Name: 2, dtype: object
# 3 Employee_ID                    104
# ...

# %%
# how to rename columns of dataframe
df.head()
# Out:
#    Employee_ID First_Name Last_Name  Birth_Date  Hire_Date      Salary Active  \
# 0          101       John     Smith  1990-05-15 2020-07-01    55000.00      Y
# 1          102      Alice   Johnson  1995-03-20 2018-04-15    60000.50
# 2          103        Bob     Brown  1985-09-10 2015-10-03    48000.75      N
# 3          104        Eva     Davis  1992-11-25 2019-02-12    62000.25      Y
# 4          105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00      N
#
#     Department
# 0           HR
# 1  Engineering
# 2      Finance
# 3    Marketing
# 4           HR

# %%
# to rename columns in a datafrane
col_names = {
                "Employee_ID": "emp_id",
                "First_Name" : "first_name",
                "Last_Name" : "last_name" 
            }

df.rename(columns=col_names, inplace=True) # inplace = True -> means changes should happen directly to original dataframe
df.head()
# Out:
#    emp_id first_name last_name  Birth_Date  Hire_Date      Salary Active  \
# 0     101       John     Smith  1990-05-15 2020-07-01    55000.00      Y
# 1     102      Alice   Johnson  1995-03-20 2018-04-15    60000.50
# 2     103        Bob     Brown  1985-09-10 2015-10-03    48000.75      N
# 3     104        Eva     Davis  1992-11-25 2019-02-12    62000.25      Y
# 4     105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00      N
#
#     Department
# 0           HR
# 1  Engineering
# 2      Finance
# 3    Marketing
# 4           HR

# %%
# to get tha column - Department == 'HR' or check if column - Department == 'Finance' 

df_HR_Finance = df[
    (df['Department'] == 'HR') 
    | 
    (df['Department'] == 'Finance')
  ]
df_HR_Finance
# Out:
#    emp_id first_name last_name  Birth_Date  Hire_Date      Salary Active  \
# 0     101       John     Smith  1990-05-15 2020-07-01    55000.00      Y
# 2     103        Bob     Brown  1985-09-10 2015-10-03    48000.75      N
# 4     105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00      N
#
#   Department
# 0         HR
# 2    Finance
# 4         HR

# %%
# to check if a column in dataframe has certain value or not
# check if Employee_ID column has

# %%
# filter df for Active - "Y" OR Active = SPACES 
df[(df["Active"] == "Y") | (df["Active"] == " ")]
# Out:
#    emp_id first_name last_name  Birth_Date  Hire_Date    Salary Active  \
# 0     101       John     Smith  1990-05-15 2020-07-01  55000.00      Y
# 1     102      Alice   Johnson  1995-03-20 2018-04-15  60000.50
# 3     104        Eva     Davis  1992-11-25 2019-02-12  62000.25      Y
#
#     Department
# 0           HR
# 1  Engineering
# 3    Marketing

# %%
# filter df for Active - "Y" OR Active = SPACES 
import numpy as np
NULL = np.nan
space_conditions = [" ", "N/A", "NULL", None, "", "None", NULL]
df[(df["Active"] == "Y") | (df["Active"].isin(space_conditions))]
# Out:
#    emp_id first_name last_name  Birth_Date  Hire_Date    Salary Active  \
# 0     101       John     Smith  1990-05-15 2020-07-01  55000.00      Y
# 1     102      Alice   Johnson  1995-03-20 2018-04-15  60000.50
# 3     104        Eva     Davis  1992-11-25 2019-02-12  62000.25      Y
#
#     Department
# 0           HR
# 1  Engineering
# 3    Marketing

# %%
import pandas as pd

# Create a sample DataFrame
data = {'Name': ['John', 'Alice', 'Bob'],
        'Age': [30, 25, 35]}
df1 = pd.DataFrame(data)
df1
# Out:
#     Name  Age
# 0   John   30
# 1  Alice   25
# 2    Bob   35

# %%
# Iterate through rows using a for loop
for index in range(len(df)):
    row = df.loc[index]
    print(row)
# Out:
# emp_id                        101
# first_name                   John
# last_name                   Smith
# Birth_Date             1990-05-15
# Hire_Date     2020-07-01 00:00:00
# Salary                    55000.0
# Active                          Y
# Department                     HR
# Name: 0, dtype: object
# emp_id                        102
# first_name                  Alice
# last_name                 Johnson
# Birth_Date             1995-03-20
# Hire_Date     2018-04-15 00:00:00
# Salary                    60000.5
# Active
# Department            Engineering
# Name: 1, dtype: object
# emp_id                        103
# first_name                    Bob
# last_name                   Brown
# Birth_Date             1985-09-10
# Hire_Date     2015-10-03 00:00:00
# Salary                   48000.75
# Active                          N
# Department                Finance
# Name: 2, dtype: object
# emp_id                        104
# first_name                    Eva
# ...

# %%
# Forward fill NaN values with method 'ffill' to fill the missing labels
# df.fillna()
df['Labels'] = df['Data'].fillna(method='ffill')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Filter out rows with NaN values in the 'Data' column
# df.notna()
df = df[df['Data'].notna()]

# Pivot the DataFrame to reshape it
result_df = df.pivot(index='Labels', columns=None, values='Data').reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Rename the columns
result_df.columns = ['Name', 'Contact', 'Address']

# Reset the index
result_df.reset_index(drop=True, inplace=True)

# Display the result
print(result_df)

# %%
# ro add new column to a dataframe using 
# insert() method
# assign() method

df.insert(0, "policy", ["AA", "BB", "CC", "DD", "AA"], True)
df
# Out:
#   policy  Employee_ID First_Name Last_Name  Birth_Date  Hire_Date      Salary  \
# 0     AA          101       John     Smith  1990-05-15 2020-07-01    55000.00
# 1     BB          102      Alice   Johnson  1995-03-20 2018-04-15    60000.50
# 2     CC          103        Bob     Brown  1985-09-10 2015-10-03    48000.75
# 3     DD          104        Eva     Davis  1992-11-25 2019-02-12    62000.25
# 4     AA          105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00
#
#    Active   Department
# 0    True           HR
# 1    True  Engineering
# 2   False      Finance
# 3    True    Marketing
# 4   False           HR

# %%
# assigm
df2 = df.assign(Address = ["Delhi", "Bangalore", "Gurgoan", "Noida", "Patna"])
df2
# Out:
#   policy  Employee_ID First_Name Last_Name  Birth_Date  Hire_Date      Salary  \
# 0     AA          101       John     Smith  1990-05-15 2020-07-01    55000.00
# 1     BB          102      Alice   Johnson  1995-03-20 2018-04-15    60000.50
# 2     CC          103        Bob     Brown  1985-09-10 2015-10-03    48000.75
# 3     DD          104        Eva     Davis  1992-11-25 2019-02-12    62000.25
# 4     AA          105  Silvester     Smith  1970-04-23 2012-06-07  1640000.00
#
#    Active   Department    Address
# 0    True           HR      Delhi
# 1    True  Engineering  Bangalore
# 2   False      Finance    Gurgoan
# 3    True    Marketing      Noida
# 4   False           HR      Patna

# %%
df_random = df['Employee_ID'].sample(2)
df_random
# Out:
# 0    101
# 1    102
# Name: Employee_ID, dtype: int64

# %%
df1
# Out:
#     Name  Age
# 0   John   30
# 1  Alice   25
# 2    Bob   35

# %%
df1.insert(2, df_random, True)
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df1.insert(2, df_random, True)
#       2 df1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5143, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5138 if allow_duplicates and not self.flags.allows_duplicate_labels:
#    5139     raise ValueError(
#    5140         "Cannot specify 'allow_duplicates=True' when "
#    5141         "'self.flags.allows_duplicate_labels' is False."
#    5142     )
# -> 5143 if not allow_duplicates and column in self.columns:
#    5144     # Should this be a different kind of error??
#    5145     raise ValueError(f"cannot insert {column}, already exists")
#    5146 if not is_integer(loc):
#
# ...
